# %%
#230701513
#VEERANDIRA SARAN R
#II CSE F
#CS23334-Fundamentals of Data Science
#Outlier Detection
import numpy as np
array=np.random.randint(1,100,16) # randomly generate 16 numbers between 1 to 100
array
# Out:
# array([72, 40, 81, 61, 85, 31,  3, 11, 86, 53, 69, 59, 94, 65, 44,  5],
#       dtype=int32)

# %%
array.mean()
# Out:
# np.float64(58.0625)

# %%
np.percentile(array,25)
# Out:
# np.float64(37.0)

# %%
np.percentile(array,50)
# Out:
# np.float64(63.0)

# %%
np.percentile(array,75)
# Out:
# np.float64(79.25)

# %%
np.percentile(array,100)
# Out:
# np.float64(94.0)

# %%
def outDetection(array):
    sorted(array)
    Q1,Q3=np.percentile(array,[25,75])
    IQR=Q3-Q1
    lr=Q1-(1.5*IQR)
    ur=Q3+(1.5*IQR)
    return lr,ur

lr,ur=outDetection(array)
lr,ur
# Out:
# (np.float64(-26.375), np.float64(142.625))

# %%
import seaborn as sns
# %matplotlib inline
sns.displot(array)

# %%
sns.distplot(array)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_9964\1133588802.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(array)
# <Axes: ylabel='Density'>

# %%
new_array=array[(array>lr) & (array<ur)]
new_array
# Out:
# array([37, 57, 79, 69, 11, 21, 80, 35, 51, 40, 84, 37, 94, 78, 72, 84],
#       dtype=int32)

# %%
sns.displot(new_array)

# %%
lr1,ur1=outDetection(new_array)
lr1,ur1
# Out:
# (np.float64(-26.375), np.float64(142.625))

# %%
final_array=new_array[(new_array>lr1) & (new_array<ur1)]
final_array
# Out:
# array([37, 57, 79, 69, 11, 21, 80, 35, 51, 40, 84, 37, 94, 78, 72, 84],
#       dtype=int32)

# %%
sns.distplot(final_array)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_9964\209491988.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(final_array)
# <Axes: ylabel='Density'>
