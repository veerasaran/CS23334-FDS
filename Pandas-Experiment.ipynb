# %%
#230701513
#VEERANDIRA SARAN R
#II CSE F
#CS23334-Fundamentals of Data Science
#Pandas-Experiment
import numpy as np
import pandas as pd
list=[[1,'Smith',50000],[2,'Jones',60000]]

df=pd.DataFrame(list)
df
# Out:
#    0      1      2
# 0  1  Smith  50000
# 1  2  Jones  60000

# %%
df.columns=['Empd','Name','Salary']
df
# Out:
#    Empd   Name  Salary
# 0     1  Smith   50000
# 1     2  Jones   60000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empd    2 non-null      int64
#  1   Name    2 non-null      object
#  2   Salary  2 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 180.0+ bytes

# %%
df=pd.read_csv('D:\\Python\\Startups.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("D:\\Python\\Employees.csv")
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %%
df.tail()
# Out:
#     EMPLOYEE_ID FIRST_NAME   LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 45          136      Hazel  Philtanker  HPHILTAN  650.127.1634  06-FEB-08
# 46          137     Renske      Ladwig   RLADWIG  650.121.1234  14-JUL-03
# 47          138    Stephen      Stiles   SSTILES  650.121.2034  26-OCT-05
# 48          139       John         Seo      JSEO  650.121.2019  12-FEB-06
# 49          140     Joshua       Patel    JPATEL  650.121.1834  06-APR-06
#
#       JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 45  ST_CLERK    2200             -         122             50
# 46  ST_CLERK    3600             -         123             50
# 47  ST_CLERK    3200             -         123             50
# 48  ST_CLERK    2700             -         123             50
# 49  ST_CLERK    2500             -         123             50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EMPLOYEE_ID     50 non-null     int64
#  1   FIRST_NAME      50 non-null     object
#  2   LAST_NAME       50 non-null     object
#  3   EMAIL           50 non-null     object
#  4   PHONE_NUMBER    50 non-null     object
#  5   HIRE_DATE       50 non-null     object
#  6   JOB_ID          50 non-null     object
#  7   SALARY          50 non-null     int64
#  8   COMMISSION_PCT  50 non-null     object
#  9   MANAGER_ID      50 non-null     object
#  10  DEPARTMENT_ID   50 non-null     int64
# dtypes: int64(3), object(8)
# memory usage: 4.4+ KB

# %%
df.SALARY
# Out:
# 0      2600
# 1      2600
# 2      4400
# 3     13000
# 4      6000
# 5      6500
# 6     10000
# 7     12008
# 8      8300
# 9     24000
# 10    17000
# 11    17000
# 12     9000
# 13     6000
# 14     4800
# 15     4800
# 16     4200
# 17    12008
# 18     9000
# 19     8200
# 20     7700
# 21     7800
# 22     6900
# 23    11000
# 24     3100
# 25     2900
# 26     2800
# 27     2600
# 28     2500
# 29     8000
# 30     8200
# 31     7900
# 32     6500
# 33     5800
# 34     3200
# 35     2700
# 36     2400
# 37     2200
# 38     3300
# 39     2800
# 40     2500
# 41     2100
# 42     3300
# 43     2900
# 44     2400
# 45     2200
# 46     3600
# 47     3200
# 48     2700
# 49     2500
# Name: SALARY, dtype: int64

# %%
type(df.SALARY)
# Out:
# pandas.core.series.Series

# %%
df.SALARY.mean()
# Out:
# np.float64(6182.32)

# %%
df.SALARY.median()
# Out:
# np.float64(4600.0)

# %%
df.SALARY.mode()
# Out:
# 0    2500
# 1    2600
# Name: SALARY, dtype: int64

# %%
df.SALARY.var()
# Out:
# np.float64(21033063.24244898)

# %%
df.SALARY.std()
# Out:
# np.float64(4586.181771631929)

# %%
df.describe()
# Out:
#        EMPLOYEE_ID        SALARY  DEPARTMENT_ID
# count    50.000000     50.000000       50.00000
# mean    134.760000   6182.320000       57.60000
# std      33.631594   4586.181772       25.11687
# min     100.000000   2100.000000       10.00000
# 25%     112.250000   2725.000000       50.00000
# 50%     124.500000   4600.000000       50.00000
# 75%     136.750000   8150.000000       60.00000
# max     206.000000  24000.000000      110.00000

# %%
df.describe(include='all')
# Out:
#         EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# count     50.000000         50        50        50            50         50
# unique          NaN         45        50        50            50         47
# top             NaN    Michael  OConnell  DOCONNEL  650.507.9833  07-JUN-02
# freq            NaN          2         1         1             1          4
# mean     134.760000        NaN       NaN       NaN           NaN        NaN
# std       33.631594        NaN       NaN       NaN           NaN        NaN
# min      100.000000        NaN       NaN       NaN           NaN        NaN
# 25%      112.250000        NaN       NaN       NaN           NaN        NaN
# 50%      124.500000        NaN       NaN       NaN           NaN        NaN
# 75%      136.750000        NaN       NaN       NaN           NaN        NaN
# max      206.000000        NaN       NaN       NaN           NaN        NaN
#
# ...

# %%
empCol=df.columns
empCol
# Out:
# Index(['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER',
#        'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID',
#        'DEPARTMENT_ID'],
#       dtype='object')

# %%
emparray=df.values
emparray
# Out:
# array([[198, 'Donald', 'OConnell', 'DOCONNEL', '650.507.9833',
#         '21-JUN-07', 'SH_CLERK', 2600, ' - ', '124', 50],
#        [199, 'Douglas', 'Grant', 'DGRANT', '650.507.9844', '13-JAN-08',
#         'SH_CLERK', 2600, ' - ', '124', 50],
#        [200, 'Jennifer', 'Whalen', 'JWHALEN', '515.123.4444',
#         '17-SEP-03', 'AD_ASST', 4400, ' - ', '101', 10],
#        [201, 'Michael', 'Hartstein', 'MHARTSTE', '515.123.5555',
#         '17-FEB-04', 'MK_MAN', 13000, ' - ', '100', 20],
#        [202, 'Pat', 'Fay', 'PFAY', '603.123.6666', '17-AUG-05', 'MK_REP',
#         6000, ' - ', '201', 20],
#        [203, 'Susan', 'Mavris', 'SMAVRIS', '515.123.7777', '07-JUN-02',
#         'HR_REP', 6500, ' - ', '101', 40],
#        [204, 'Hermann', 'Baer', 'HBAER', '515.123.8888', '07-JUN-02',
#         'PR_REP', 10000, ' - ', '101', 70],
#        [205, 'Shelley', 'Higgins', 'SHIGGINS', '515.123.8080',
#         '07-JUN-02', 'AC_MGR', 12008, ' - ', '101', 110],
# ...
